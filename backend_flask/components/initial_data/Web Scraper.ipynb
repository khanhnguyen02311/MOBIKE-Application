# %% [markdown]
# #### Using data from okxe.vn

# %%
from urllib.request import urlopen
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = "https://webscraper.io/test-sites/tables"

# %%
html_code = urlopen(url).read().decode("utf-8")
soup = BeautifulSoup(html_code)

# %%
soup.find_all("h2")
# Out:
# [<h2>Semantically correct table with thead and tbody</h2>,
#  <h2>Table without thead tag</h2>,
#  <h2>Table with multiple header rows and an empty data row</h2>]

# %% [markdown]
# -----------------------------

# %%
brands_url = "https://api.okxe.vn/api/v2/brands?is_active=1"
models_url = "https://api.okxe.vn/api/v2/models?brand_id=1&is_active=1"
posts_url = "https://api.okxe.vn/api/v2/products?sort_of=product_new&page=1&per_page=256"
colors_url = "https://api.okxe.vn/api/v2/colors"

# %%
brands_data = requests.get(brands_url)
posts_data = requests.get(posts_url)
models_data = requests.get(models_url)
colors_data = requests.get(colors_url)

# %%
posts_data.json()
# Out:
# {'success': True,
#  'result_code': 1,
#  'result': 'Ok',
#  'data': [{'used_status': 'used',
#    'fuel': 'gasolin',
#    'used_distance': 10000,
#    'total_views': 0,
#    'type': '1',
#    'location_id': 1,
#    'q_product_name': 'Yamaha Janus 2019 2018',
#    'price': 15800000,
#    'seo_description': None,
#    'model': {'is_active': 1,
#     'updated_at': '2019-09-25 16:22:56',
#     'sort_num': 99,
#     'name': 'Janus',
#     'created_at': '2019-09-25 16:22:56',
#     'id': 525,
#     'deleted_at': None,
#     'brand_id': 40},
#    'detail_model': {'user_admin_id': 0,
#     'note': '',
#     'is_active': 1,
#     'fuel': 'Gasolin',
#     'created_at': '2019-09-25 16:22:56',
#     'model_id': 525,
#     'type': 'Xe tay ga',
#     'deleted_at': None,
#     'updated_at': '2022-01-11 00:46:09',
#     'engine': '125',
#     'sort_num': 99,
#     'name': '2019',
#     'old_id': None,
#     'id': 1314,
#     'gear': 'Auto'},
#    'id': 1195010,
#    'stock': 1,
#    'brand': {'is_active': 1,
#     'active_logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Yamaha.png',
#     'sort_num': 1,
#     'name': 'Yamaha',
#     'inactive_logo': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Yamaha.png',
#     'id': 40,
#     'deleted_at': None},
#    'q_used_status': 'used',
#    'sales_volume': 0,
#    'image': {'small': 'https://cdn.okxe.vn/products/10/1195010/1195010_269768_z3523739714953_dbe5b1b9cad6de61da26b3f89cc054a0_20221205103409_wTzmsSIT_s_160x160.jpg',
#     'fhd': 'https://cdn.okxe.vn/products/10/1195010/1195010_269768_z3523739714953_dbe5b1b9cad6de61da26b3f89cc054a0_20221205103409_wTzmsSIT_f_1920x1080.jpg',
#     'original': 'https://cdn.okxe.vn/products/10/1195010/1195010-269768-z3523739714953-dbe5b1b9cad6de61da26b3f89cc054a0-20221205103409-wtzmssit_o.jpg',
#     'large': 'https://cdn.okxe.vn/products/10/1195010/1195010_269768_z3523739714953_dbe5b1b9cad6de61da26b3f89cc054a0_20221205103409_wTzmsSIT_l_800x800.jpg',
#     'created_at': '2022-12-05T10:34:09+07:00',
#     'main': 1,
#     'label': ' ',
#     'medium': 'https://cdn.okxe.vn/products/10/1195010/1195010_269768_z3523739714953_dbe5b1b9cad6de61da26b3f89cc054a0_20221205103409_wTzmsSIT_m_400x400.jpg',
#     'deleted_at': None,
#     'updated_at': '2022-12-05T10:34:09+07:00',
#     'product_id': 1195010,
#     'id': 6914718,
#     'order': 0},
#    'used_year': 4,
#    'like': [],
#    'release_year': 201804,
#    'deleted_at': None,
#    'created_by': None,
#    'product_name': 'Yamaha Janus 2019',
#    'brand_id': 40,
#    'detail_model_id': 1314,
#    'gear': 'auto',
#    'is_qualified': 0,
#    'last_changed_by': 'auto',
#    'color': [{'color_id': 3,
#      'updated_at': '2022-12-05 10:34:09',
#      'product_id': 1195010,
#      'created_at': '2022-12-05 10:34:09',
#      'id': 1177715,
#      'color_name': 'black',
#      'deleted_at': None}],
#    'is_station': 1,
#    'description': 'CỬA H&Agrave;NG CAM KẾT CHẤT LƯỢNG - BẢO H&Agrave;NH CH&Iacute;NH H&Atilde;NG\r\n🏆YAMAHA JANUS M&Agrave;U ĐEN 2018\r\n✔ Chủ xe giữ g&igrave;n chăm s&oacute;c cực k&igrave; cẩn thận, chất xe mới\r\n✔ Xe đẹp như h&igrave;nh, m&aacute;y &ecirc;m, kh&ocirc;ng lỗi\r\n✔ Hỗ trợ k&yacute; ủy quyền hoặc r&uacute;t hồ sơ cho anh em muốn đổi biển số\r\nSdt 0363.399.066',
#    'created_at': '2022-12-05T10:34:09+07:00',
#    'inspection_date': None,
#    'product_code': 'ptXUTRIQBG',
#    'sales_status': 'ing',
#    'updated_at': '2022-12-05T10:34:11+07:00',
#    'engine': '125',
#    'bike_slug': 'yamaha-janus-2019',
#    'store_id': 269743,
#    'q_release_year': '2018',
#    'model_id': 525,
#    'store': {'is_certified': True,
#     'rating': 5,
#     'description': 'Cửa hàng Mua bán trao đổi Xe máy cũ Lộc Phát Motor luôn duy trì 400 xe ga, xe số đầy đủ mẫu mã các loại để phục vụ khách hàng chu đáo nhất. Bảo hành dài hạn, sang tên đổi chủ cho bạn nào có nhu cầu sử dụng. Đc : 336 đường Nguyễn Văn Giáp Cầu Diễn sau sân vận động Mỹ Đình, Hà nội. *** XE GÌ CŨNG CÓ Giấy tờ đầy đủ Bao SANG TÊN Nhanh.',
#     'created_at': '2020-11-03 10:01:48',
#     'location_id': 1,
#     'suspended_reason': None,
#     'name_slug': 'xmlocphat',
#     'updated_at': '2022-10-03 21:25:33',
#     'number_of_review': 905,
#     'number_of_sales': 904,
#     'id': 269743,
#     'lat': None,
#     'location_certify': 0,
#     'store_code': 'OKXE-STR-9F9B51DE-1',
#     'image': 'https://cdn.okxe.vn/stores/743/269743/J6VxIO6B5GrQp12eGPtUp4KgMomEbgj7Zh70BPCC.jpg',
#     'address': None,
#     'lng': None,
#     'number_of_days': 762,
#     'store_type': 'alliance',
#     'number_of_likes': 365,
#     'deleted_at': None,
#     'user_id': 269768,
#     'phone': '0363399066',
#     'name': 'xe máy Lộc Phát',
#     'number_of_products': 2307,
#     'is_loanable': 1,
#     'user': {'marked_contents': '{"posting_rule": {"time": "2022-10-23 09:27:39", "marked": true}}',
#      'is_verify': 2,
#      'avatar': 'https://cdn.okxe.vn/stores/avatar/768/269768/92N1hb0csraoEYpmej40AGTiUEZg8dS5ogmvHioM.jpg',
#      'type': 'alliance',
#      'is_manager': False,
#      'has_sendbird': 1,
#      'status_updated_by': None,
#      'is_seller': '2',
#      'updated_at': '2022-10-23 09:27:39',
#      'updated_name_at': None,
#      'nickname': 'xe máy Lộc Phát',
#      'id': 269768,
#      'sync_data': None,
#      'sync_user_id': None,
#      'username': 'XmLocPhat',
#      'status': 'active',
#      'status_updated_at': None}},
#    'seo_title': None,
#    'license_plate': None,
#    'blocked_reason': None,
#    'q_color': [{'color_id': 3,
#      'updated_at': '2022-12-05 10:34:09',
#      'product_id': 1195010,
#      'created_at': '2022-12-05 10:34:09',
#      'id': 1177715,
#      'color_name': 'black',
#      'deleted_at': None}],
#    'location': {'is_active': 1,
#     'code': '3',
#     'updated_at': None,
#     'sort_num': 1,
#     'area_code': 'H004',
#     'name': 'Tp. Hà Nội',
#     'created_at': None,
#     'city_code': 'ha-noi',
#     'id': 1,
#     'province_code': '024',
#     'loan_accept': 1,
#     'zip_code': '100000'},
#    'is_inspection': 1,
#    'advertise': None,
#    'has_liked': False}],
#  'extra_data': {'total_value': 10000}}

# %%
brands_data.json()['data']
# Out:
# [{'id': 1,
#   'name': 'Aprillia',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Aprilia.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Aprilia.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 2,
#   'name': 'Bajaj',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Bajaj.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Bajaj.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 3,
#   'name': 'Benelli',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Benelli.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Benelli.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 4,
#   'name': 'BMW',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/BMW.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/BMW.png',
#   'sort_num': 1,
#   'is_active': 1},
#  {'id': 5,
#   'name': 'Brixton',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Brixtion.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Brixtion.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 6,
#   'name': 'CPI',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/CPI.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/CPI.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 7,
#   'name': 'CR&S',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/CR%26S.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/CR%26S.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 8,
#   'name': 'Daelim',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Daelim.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Daelim.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 9,
#   'name': 'Ducati',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Ducati.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Ducati.png',
#   'sort_num': 1,
#   'is_active': 1},
#  {'id': 10,
#   'name': 'Euro Reibel',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Euro+Reibel.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Euro+Reibel.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 11,
#   'name': 'Generic',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Generic.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Generic.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 12,
#   'name': 'Halim',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Halim.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Halim.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 13,
#   'name': 'Harley Davidson',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Harley+Davidson.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Harley+Davidson.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 14,
#   'name': 'Hero Honda',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Hero.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Hero.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 15,
#   'name': 'Honda',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Honda.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Honda.png',
#   'sort_num': 1,
#   'is_active': 1},
#  {'id': 16,
#   'name': 'Hyosung',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Hyosung.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Hyosung.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 17,
#   'name': 'Kawasaki',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Kawasaki.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Kawasaki.png',
#   'sort_num': 1,
#   'is_active': 1},
#  {'id': 18,
#   'name': 'Keeway',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Keeway.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Keeway.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 19,
#   'name': 'Kengo',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Kengo.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Kengo.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 20,
#   'name': 'KTM',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/KTM.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/KTM.png',
#   'sort_num': 1,
#   'is_active': 1},
#  {'id': 21,
#   'name': 'Kymco',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Kymco.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Kymco.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 22,
#   'name': 'Lambretta',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Lambretta.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Lambretta.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 23,
#   'name': 'Malaguti',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Malaguti.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Malaguti.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 24,
#   'name': 'Mobylette',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Mobylette.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Mobylette.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 25,
#   'name': 'Moto Guzzi',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Moto+Guzzi.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Moto+Guzzi.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 26,
#   'name': 'MV Agusta',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/MV+Augusta.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/MV+Augusta.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 27,
#   'name': 'Norton',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Norton.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Norton.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 28,
#   'name': 'Peugeot',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Peugeot.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Peugeot.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 29,
#   'name': 'Piaggio',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Piaggio.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Piaggio.png',
#   'sort_num': 1,
#   'is_active': 1},
#  {'id': 30,
#   'name': 'RebelUSA',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/RebelUSA.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/RebelUSA.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 31,
#   'name': 'Regal Raptor',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Regal+Raptor.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Regal+Raptor.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 32,
#   'name': 'Sachs',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Sachs.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Sachs.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 33,
#   'name': 'Sanda',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Sanda.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Sanda.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 34,
#   'name': 'Suzuki',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Suzuki.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Suzuki.png',
#   'sort_num': 1,
#   'is_active': 1},
#  {'id': 35,
#   'name': 'SYM',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/SYM.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/SYM.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 36,
#   'name': 'Triumph',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Triumph.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Triumph.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 37,
#   'name': 'Vento',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Vento.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Vento.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 38,
#   'name': 'Victory',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Victory.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Victory.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 39,
#   'name': 'Visitor',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Visitor.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Visitor.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 40,
#   'name': 'Yamaha',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Yamaha.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Yamaha.png',
#   'sort_num': 1,
#   'is_active': 1},
#  {'id': 41,
#   'name': 'ALPHA',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Visitor.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Visitor.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 42,
#   'name': 'Asama',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Asama.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Asama.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 43,
#   'name': 'ASISTA Bmm',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/ASISTA+Bmm.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/ASISTA+Bmm.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 44,
#   'name': 'Hyundai',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Huyndai.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Huyndai.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 45,
#   'name': 'Suzika',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Suzika.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Suzika.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 46,
#   'name': 'AIMA',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Aima.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Aima.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 47,
#   'name': 'Dkbike',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Dkbike.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Dkbike.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 48,
#   'name': 'Draca',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Draca.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Draca.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 49,
#   'name': 'Anbico Dina',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/ANBICO+DINA.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/ANBICO+DINA.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 50,
#   'name': 'ANBICO',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/ANBICO.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/ANBICO.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 51,
#   'name': 'Before All',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before+All.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Before+All.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 52,
#   'name': 'Dibao',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Dibao.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Dibao.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 53,
#   'name': 'HTC',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/HTC.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/HTC.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 54,
#   'name': 'Giant',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Giant.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Giant.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 55,
#   'name': 'DTP',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/DTP.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/DTP.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 56,
#   'name': 'Espero',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Espero.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Espero.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 57,
#   'name': 'Everest',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Everest.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Everest.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 58,
#   'name': 'FMT',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/FMT.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/FMT.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 59,
#   'name': 'Gianya',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Gianya.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Gianya.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 60,
#   'name': 'Hola',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Hola.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Hola.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 61,
#   'name': 'Nishiki',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Nishiki.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Nishiki.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 62,
#   'name': 'Sonsu',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Sonsu.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Sonsu.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 63,
#   'name': 'Gedesheng',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Gedesheng.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Gedesheng.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 64,
#   'name': 'Fuji',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Fuji.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Fuji.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 65,
#   'name': 'Hkbike',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Hkbike.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Hkbike.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 66,
#   'name': 'Osakar',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Osakar.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Osakar.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 67,
#   'name': 'Zoomer',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Zoomer.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Zoomer.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 68,
#   'name': 'Jili',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Jili.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Jili.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 69,
#   'name': 'Mocha',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Mocha.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Mocha.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 70,
#   'name': 'Nijia',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Nijia.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Nijia.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 71,
#   'name': 'Pega',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Pega.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Pega.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 72,
#   'name': 'Sufat',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Sufat.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Sufat.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 73,
#   'name': 'Takuda',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Takuda.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Takuda.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 74,
#   'name': 'Byvin',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Byvin.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Byvin.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 75,
#   'name': 'Emoto',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Emoto.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Emoto.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 76,
#   'name': 'JVC Eco',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/JVC+eco.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/JVC+eco.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 77,
#   'name': 'Seeyes',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Seeyes.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Seeyes.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 78,
#   'name': 'Việt Thái',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Vi%E1%BB%87t+Th%C3%A1i.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Vi%E1%BB%87t+Th%C3%A1i.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 79,
#   'name': 'Yadea',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Yadea.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Yadea.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 80,
#   'name': 'CMV',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/CMV.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/CMV.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 81,
#   'name': 'EV',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/EV.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/EV.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 82,
#   'name': 'VinFast',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Vinfast.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Vinfast.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 83,
#   'name': 'DYU',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/DYU.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/DYU.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 84,
#   'name': 'Lyva',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Lyva.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Lyva.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 85,
#   'name': 'Kingda',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Kingda.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Kingda.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 86,
#   'name': 'Ecobike',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Ecobike.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Ecobike.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 87,
#   'name': 'Nikebike',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Nike+bike.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Nike+bike.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 88,
#   'name': 'Tenbike',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Tenbike.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Tenbike.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 89,
#   'name': 'Haybike',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Haybike.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Haybike.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 90,
#   'name': 'Dragon',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Dragon.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Dragon.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 91,
#   'name': 'Michi',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Michi.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Michi.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 92,
#   'name': 'Ecooter',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Ecooter.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Ecooter.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 93,
#   'name': 'Niu',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Niu.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Niu.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 94,
#   'name': 'ETC',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/ETC.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/ETC.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 95,
#   'name': 'GPX',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/GPX.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/GPX.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 96,
#   'name': 'Royal Enfield',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Royal+Enfield.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Royal+Enfield.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 97,
#   'name': 'Sunny',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Sunny.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Sunny.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 98,
#   'name': 'PK',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/PK.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/PK.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 99,
#   'name': 'The Design Tiger',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/The%20Design%20Tiger.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/The%20Design%20Tiger.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 100,
#   'name': 'HT Bike',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/HTbike.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/HTbike.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 102,
#   'name': 'LTP',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/LTP.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/LTP.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 104,
#   'name': 'TL bike',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/TL+bike.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/TL+bike.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 105,
#   'name': 'Martin',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Martin.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Martin.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 106,
#   'name': 'Yasuki',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Yasuki.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Yasuki.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 107,
#   'name': 'AVA',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Ava.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Ava.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 108,
#   'name': 'Hitasa',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Hitasa.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Hitasa.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 110,
#   'name': 'Covingtons',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Covingtons.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Covingtons.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 114,
#   'name': 'T-bike',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/T-bike.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/T-bike.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 115,
#   'name': 'Bridgestone',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Bridgestone.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Bridgestone.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 116,
#   'name': 'Taya Motor',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/linh_1626162982.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/linh_1626162982.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 117,
#   'name': 'Bosscity',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/linh_1626690942.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/linh_1626690942.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 118,
#   'name': 'Ally',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/linh_1626691252.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/linh_1626691252.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 119,
#   'name': 'Nioshima',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/linh_1626692067.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/linh_1626692067.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 120,
#   'name': 'Myoko',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/linh_1634533522.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/linh_1634533522.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 121,
#   'name': 'DETECH',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/linh_1634710030.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/linh_1634710030.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 122,
#   'name': 'Giorno',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/linh_1635156603.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/linh_1635156603.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 123,
#   'name': 'CUB',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 124,
#   'name': 'Gogoro',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/linh_1635477179.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/linh_1635477179.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 125,
#   'name': 'DK MOTOR',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 126,
#   'name': 'Anmshi',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 127,
#   'name': 'Arena',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 128,
#   'name': 'Crea',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 129,
#   'name': 'D Bike',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 130,
#   'name': 'Dealim',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 132,
#   'name': 'DK',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 134,
#   'name': 'GLX',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/linh_1636961118.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/linh_1636961118.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 135,
#   'name': 'Vinathai',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 136,
#   'name': 'Saki',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 137,
#   'name': 'Sadoka',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 138,
#   'name': 'LIXI',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 139,
#   'name': 'Lifan',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 140,
#   'name': 'Victoria',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 141,
#   'name': 'Taya Motor',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 143,
#   'name': 'Lima',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/linh_1637567702.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 144,
#   'name': 'Evgo',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/active/2021/Before.png',
#   'sort_num': 99,
#   'is_active': 1},
#  {'id': 145,
#   'name': 'Husqvarna',
#   'logo': 'https://cdn.okxe.vn/moto/logo/active/linh_1639388345.png',
#   'logo_normal': 'https://cdn.okxe.vn/moto/logo/inactive/linh_1639388345.png',
#   'sort_num': 99,
#   'is_active': 1}]

# %%
models_data.json()['data']
# Out:
# [{'id': 1,
#   'name': 'Caponord',
#   'image': 'https://s3-ap-southeast-1.amazonaws.com/okxe.2019/moto/icon/bike_icon2.png'},
#  {'id': 3,
#   'name': 'SR Motard',
#   'image': 'https://s3-ap-southeast-1.amazonaws.com/okxe.2019/moto/icon/bike_icon2.png'},
#  {'id': 5,
#   'name': 'RSV4',
#   'image': 'https://s3-ap-southeast-1.amazonaws.com/okxe.2019/moto/icon/bike_icon2.png'},
#  {'id': 6,
#   'name': 'Tuono V4',
#   'image': 'https://s3-ap-southeast-1.amazonaws.com/okxe.2019/moto/icon/bike_icon2.png'},
#  {'id': 1159,
#   'name': 'Dorsoduro',
#   'image': 'https://s3-ap-southeast-1.amazonaws.com/okxe.2019/moto/icon/bike_icon2.png'},
#  {'id': 1163,
#   'name': 'S4',
#   'image': 'https://s3-ap-southeast-1.amazonaws.com/okxe.2019/moto/icon/bike_icon2.png'},
#  {'id': 1164,
#   'name': 'Shiver',
#   'image': 'https://s3-ap-southeast-1.amazonaws.com/okxe.2019/moto/icon/bike_icon2.png'},
#  {'id': 1166,
#   'name': 'Tuono',
#   'image': 'https://s3-ap-southeast-1.amazonaws.com/okxe.2019/moto/icon/bike_icon2.png'}]

# %%
posts_data.json()['data']
# Out:
# [{'used_status': 'used',
#   'fuel': 'gasolin',
#   'used_distance': 10000,
#   'total_views': 0,
#   'type': '1',
#   'location_id': 1,
#   'q_product_name': 'Yamaha Janus 2019 2018',
#   'price': 15800000,
#   'seo_description': None,
#   'model': {'is_active': 1,
#    'updated_at': '2019-09-25 16:22:56',
#    'sort_num': 99,
#    'name': 'Janus',
#    'created_at': '2019-09-25 16:22:56',
#    'id': 525,
#    'deleted_at': None,
#    'brand_id': 40},
#   'detail_model': {'user_admin_id': 0,
#    'note': '',
#    'is_active': 1,
#    'fuel': 'Gasolin',
#    'created_at': '2019-09-25 16:22:56',
#    'model_id': 525,
#    'type': 'Xe tay ga',
#    'deleted_at': None,
#    'updated_at': '2022-01-11 00:46:09',
#    'engine': '125',
#    'sort_num': 99,
#    'name': '2019',
#    'old_id': None,
#    'id': 1314,
#    'gear': 'Auto'},
#   'id': 1195010,
#   'stock': 1,
#   'brand': {'is_active': 1,
#    'active_logo': 'https://cdn.okxe.vn/moto/logo/active/2021/Yamaha.png',
#    'sort_num': 1,
#    'name': 'Yamaha',
#    'inactive_logo': 'https://cdn.okxe.vn/moto/logo/inactive/2021/Yamaha.png',
#    'id': 40,
#    'deleted_at': None},
#   'q_used_status': 'used',
#   'sales_volume': 0,
#   'image': {'small': 'https://cdn.okxe.vn/products/10/1195010/1195010_269768_z3523739714953_dbe5b1b9cad6de61da26b3f89cc054a0_20221205103409_wTzmsSIT_s_160x160.jpg',
#    'fhd': 'https://cdn.okxe.vn/products/10/1195010/1195010_269768_z3523739714953_dbe5b1b9cad6de61da26b3f89cc054a0_20221205103409_wTzmsSIT_f_1920x1080.jpg',
#    'original': 'https://cdn.okxe.vn/products/10/1195010/1195010-269768-z3523739714953-dbe5b1b9cad6de61da26b3f89cc054a0-20221205103409-wtzmssit_o.jpg',
#    'large': 'https://cdn.okxe.vn/products/10/1195010/1195010_269768_z3523739714953_dbe5b1b9cad6de61da26b3f89cc054a0_20221205103409_wTzmsSIT_l_800x800.jpg',
#    'created_at': '2022-12-05T10:34:09+07:00',
#    'main': 1,
#    'label': ' ',
#    'medium': 'https://cdn.okxe.vn/products/10/1195010/1195010_269768_z3523739714953_dbe5b1b9cad6de61da26b3f89cc054a0_20221205103409_wTzmsSIT_m_400x400.jpg',
#    'deleted_at': None,
#    'updated_at': '2022-12-05T10:34:09+07:00',
#    'product_id': 1195010,
#    'id': 6914718,
#    'order': 0},
#   'used_year': 4,
#   'like': [],
#   'release_year': 201804,
#   'deleted_at': None,
#   'created_by': None,
#   'product_name': 'Yamaha Janus 2019',
#   'brand_id': 40,
#   'detail_model_id': 1314,
#   'gear': 'auto',
#   'is_qualified': 0,
#   'last_changed_by': 'auto',
#   'color': [{'color_id': 3,
#     'updated_at': '2022-12-05 10:34:09',
#     'product_id': 1195010,
#     'created_at': '2022-12-05 10:34:09',
#     'id': 1177715,
#     'color_name': 'black',
#     'deleted_at': None}],
#   'is_station': 1,
#   'description': 'CỬA H&Agrave;NG CAM KẾT CHẤT LƯỢNG - BẢO H&Agrave;NH CH&Iacute;NH H&Atilde;NG\r\n🏆YAMAHA JANUS M&Agrave;U ĐEN 2018\r\n✔ Chủ xe giữ g&igrave;n chăm s&oacute;c cực k&igrave; cẩn thận, chất xe mới\r\n✔ Xe đẹp như h&igrave;nh, m&aacute;y &ecirc;m, kh&ocirc;ng lỗi\r\n✔ Hỗ trợ k&yacute; ủy quyền hoặc r&uacute;t hồ sơ cho anh em muốn đổi biển số\r\nSdt 0363.399.066',
#   'created_at': '2022-12-05T10:34:09+07:00',
#   'inspection_date': None,
#   'product_code': 'ptXUTRIQBG',
#   'sales_status': 'ing',
#   'updated_at': '2022-12-05T10:34:11+07:00',
#   'engine': '125',
#   'bike_slug': 'yamaha-janus-2019',
#   'store_id': 269743,
#   'q_release_year': '2018',
#   'model_id': 525,
#   'store': {'is_certified': True,
#    'rating': 5,
#    'description': 'Cửa hàng Mua bán trao đổi Xe máy cũ Lộc Phát Motor luôn duy trì 400 xe ga, xe số đầy đủ mẫu mã các loại để phục vụ khách hàng chu đáo nhất. Bảo hành dài hạn, sang tên đổi chủ cho bạn nào có nhu cầu sử dụng. Đc : 336 đường Nguyễn Văn Giáp Cầu Diễn sau sân vận động Mỹ Đình, Hà nội. *** XE GÌ CŨNG CÓ Giấy tờ đầy đủ Bao SANG TÊN Nhanh.',
#    'created_at': '2020-11-03 10:01:48',
#    'location_id': 1,
#    'suspended_reason': None,
#    'name_slug': 'xmlocphat',
#    'updated_at': '2022-10-03 21:25:33',
#    'number_of_review': 905,
#    'number_of_sales': 904,
#    'id': 269743,
#    'lat': None,
#    'location_certify': 0,
#    'store_code': 'OKXE-STR-9F9B51DE-1',
#    'image': 'https://cdn.okxe.vn/stores/743/269743/J6VxIO6B5GrQp12eGPtUp4KgMomEbgj7Zh70BPCC.jpg',
#    'address': None,
#    'lng': None,
#    'number_of_days': 762,
#    'store_type': 'alliance',
#    'number_of_likes': 365,
#    'deleted_at': None,
#    'user_id': 269768,
#    'phone': '0363399066',
#    'name': 'xe máy Lộc Phát',
#    'number_of_products': 2307,
#    'is_loanable': 1,
#    'user': {'marked_contents': '{"posting_rule": {"time": "2022-10-23 09:27:39", "marked": true}}',
#     'is_verify': 2,
#     'avatar': 'https://cdn.okxe.vn/stores/avatar/768/269768/92N1hb0csraoEYpmej40AGTiUEZg8dS5ogmvHioM.jpg',
#     'type': 'alliance',
#     'is_manager': False,
#     'has_sendbird': 1,
#     'status_updated_by': None,
#     'is_seller': '2',
#     'updated_at': '2022-10-23 09:27:39',
#     'updated_name_at': None,
#     'nickname': 'xe máy Lộc Phát',
#     'id': 269768,
#     'sync_data': None,
#     'sync_user_id': None,
#     'username': 'XmLocPhat',
#     'status': 'active',
#     'status_updated_at': None}},
#   'seo_title': None,
#   'license_plate': None,
#   'blocked_reason': None,
#   'q_color': [{'color_id': 3,
#     'updated_at': '2022-12-05 10:34:09',
#     'product_id': 1195010,
#     'created_at': '2022-12-05 10:34:09',
#     'id': 1177715,
#     'color_name': 'black',
#     'deleted_at': None}],
#   'location': {'is_active': 1,
#    'code': '3',
#    'updated_at': None,
#    'sort_num': 1,
#    'area_code': 'H004',
#    'name': 'Tp. Hà Nội',
#    'created_at': None,
#    'city_code': 'ha-noi',
#    'id': 1,
#    'province_code': '024',
#    'loan_accept': 1,
#    'zip_code': '100000'},
#   'is_inspection': 1,
#   'advertise': None,
#   'has_liked': False}]

# %%
post = posts_data.json()['data'][0]

# %%
att_Vehicle_name = post['product_name']
att_Odometer = post['used_distance']
att_License_plate = post['license_plate']
att_Cubic_power = post['engine']
att_Manufacture_year = post['release_year']
att_City = post['location']['name']
att_ID_VehicleBrand = post['brand_id']
att_ID_VehicleLineup = post['model']['id']
att_Condition = post['used_status']
att_ID_VehicleType = post['type']
att_ID_Color = post['color'][0]['color_id']

# %%
att_Vehicle_name, att_Odometer, att_License_plate, att_Cubic_power, att_Manufacture_year, att_City, att_ID_VehicleBrand, att_ID_VehicleLineup, att_Condition, att_ID_VehicleType, att_ID_Color
# Out:
# ('Yamaha Janus 2019',
#  10000,
#  None,
#  '125',
#  201804,
#  'Tp. Hà Nội',
#  40,
#  525,
#  'used',
#  '1',
#  3)

# %%
att_Title = post['q_product_name']
att_Content = post['description']
att_Pricetag = post['price']

att_Image = post['image']['medium']

# %%
att_Title, att_Content, att_Pricetag, att_Image
# Out:
# ('Yamaha Janus 2019 2018',
#  'CỬA H&Agrave;NG CAM KẾT CHẤT LƯỢNG - BẢO H&Agrave;NH CH&Iacute;NH H&Atilde;NG\r\n🏆YAMAHA JANUS M&Agrave;U ĐEN 2018\r\n✔ Chủ xe giữ g&igrave;n chăm s&oacute;c cực k&igrave; cẩn thận, chất xe mới\r\n✔ Xe đẹp như h&igrave;nh, m&aacute;y &ecirc;m, kh&ocirc;ng lỗi\r\n✔ Hỗ trợ k&yacute; ủy quyền hoặc r&uacute;t hồ sơ cho anh em muốn đổi biển số\r\nSdt 0363.399.066',
#  15800000,
#  'https://cdn.okxe.vn/products/10/1195010/1195010_269768_z3523739714953_dbe5b1b9cad6de61da26b3f89cc054a0_20221205103409_wTzmsSIT_m_400x400.jpg')

# %% [markdown]
# -----

# %%
brands_table = pd.DataFrame(data=brands_data.json()['data']).drop(labels=['logo_normal', 'sort_num', 'is_active'], axis=1)

# %%
brands_table
# Out:
#       id        name                                               logo
# 0      1    Aprillia  https://cdn.okxe.vn/moto/logo/active/2021/Apri...
# 1      2       Bajaj  https://cdn.okxe.vn/moto/logo/active/2021/Baja...
# 2      3     Benelli  https://cdn.okxe.vn/moto/logo/active/2021/Bene...
# 3      4         BMW  https://cdn.okxe.vn/moto/logo/active/2021/BMW.png
# 4      5     Brixton  https://cdn.okxe.vn/moto/logo/active/2021/Brix...
# ..   ...         ...                                                ...
# 131  140    Victoria  https://cdn.okxe.vn/moto/logo/active/2021/Befo...
# 132  141  Taya Motor  https://cdn.okxe.vn/moto/logo/active/2021/Befo...
# 133  143        Lima  https://cdn.okxe.vn/moto/logo/active/2021/Befo...
# 134  144        Evgo  https://cdn.okxe.vn/moto/logo/active/2021/Befo...
# 135  145   Husqvarna  https://cdn.okxe.vn/moto/logo/active/linh_1639...
#
# [136 rows x 3 columns]

# %%
total_data = []
for index, row in brands_table.iterrows():
   url = f"https://api.okxe.vn/api/v2/models?brand_id={row['id']}&is_active=1"
   data = requests.get(url).json()['data']
   for i in data:
      i['brand_id'] = row['id']
      total_data.append(i)

# %%
models_table = pd.DataFrame(data=total_data).drop(columns=['image'])

# %%
models_table
# Out:
#         id        name  brand_id
# 0        1    Caponord         1
# 1        3   SR Motard         1
# 2        5        RSV4         1
# 3        6    Tuono V4         1
# 4     1159   Dorsoduro         1
# ...    ...         ...       ...
# 1240  1693           C       144
# 1241  1694           A       144
# 1242  1683      Enduro       145
# 1243  1684   Supermoto       145
# 1244  1685  Svartpilen       145
#
# [1245 rows x 3 columns]

# %%
colors_table = pd.DataFrame(data=colors_data.json()['data'])

# %%
colors_table
# Out:
#     id     name color_code
# 0    1    white       None
# 1    2    ivory       None
# 2    3    black       None
# 3    4   silver       None
# 4    5     gray       None
# 5    6     gold       None
# 6    7    brown       None
# 7    8   yellow       None
# 8    9   orange       None
# 9   10      red       None
# 10  11     pink       None
# 11  12   purple       None
# 12  13    green       None
# 13  14  skyblue       None
# 14  15     blue       None
# 15  16      etc       None

# %%
num_request = 256
total_post = []
total_vehicleinfo = []

url = f"https://api.okxe.vn/api/v2/products?sort_of=product_new&page=1&per_page={num_request}&include=advertisement"
data = requests.get(url).json()['data']
for j in range(num_request):
   item = data[j]
   vehicle_info = {
      'infoid': j + 1,
      'Vehicle_name': item['product_name'],
      'Odometer': item['used_distance'],
      'License_plate': item['license_plate'],
      'Cubic_power': item['engine'],
      'Manufacture_year': item['release_year'],
      'ID_VehicleBrand': item['brand_id'],
      'ID_VehicleLineup': item['model']['id'],
      'Condition': item['used_status'],
      'ID_VehicleType': item['type'],
      'ID_Color': item['color'][0]['color_id']
   }
   post = {
      'Title': item['q_product_name'],
      'Content': item['description'],
      'Pricetag': item['price'],
      'Image': item['image']['medium'],
      'City_name': item['location']['name'],
      'ID_VehicleInfo': j + 1
   }
   print(item['product_name'] or '###' + " - " + item['license_plate'] or '###')
   total_vehicleinfo.append(vehicle_info)
   total_post.append(post)
# Out:
# Yamaha Latte
# SYM Angel 110
# Harley Davidson Forty-Eight Special
# Harley Davidson Street 750
# Suzuki GZ 150A
# Honda SH 150
# Honda SH 150
# Honda Air Blade 125 FI
# Honda Wave Alpha 100
# Honda Future 125
# Honda Vision NSC110
# Piaggio Liberty 125
# Piaggio Zip 100
# Honda Winner X 150
# Honda Future 125
# Piaggio Liberty 125
# Honda Vision 110
# Honda Air Blade 110 FI
# Honda Air Blade 110 FI
# Honda Air Blade 110 FI
# Honda Air Blade 125 FI
# Honda Winner 150
# Honda Vision 110
# Yamaha Exciter 150
# Yamaha Exciter 150
# Piaggio Liberty 125
# Honda Vision 110
# Yamaha Exciter 150
# Honda Air Blade 110 FI
# Yamaha Exciter 150
# Yamaha Exciter 150
# Yamaha Janus 2019
# Honda Air Blade 110 FI
# SYM Elizabeth Standard
# Honda Super Cub 50
# Honda Vision 110
# Ducati Mini 110
# Yamaha Exciter 150 RC
# Honda LEAD 125 FI
# SYM Shark 150
# Yamaha Sirius Fi
# Brixton Scrambler 150
# Honda SH Mode 125
# Yamaha Jupiter FI
# Ducati Monster 795
# Yamaha Exciter 150
# Yamaha NVX 155 ABS
# Suzuki Husky 125
# Honda Wave Alpha 110
# Honda Vision 110
# Suzuki GD 110
# Yamaha NVX 155 ABS
# Yamaha TFX 150
# Honda Wave Alpha 110
# Piaggio Vespa LX
# Yamaha Jupiter FI
# Piaggio Vespa S125 i.e
# Yamaha NVX 155 ABS
# Honda Vision 110
# Piaggio Zip 100
# MV Agusta Dragster 800
# Suzuki GZ 150A
# Honda LEAD 125 FI
# Honda Future 125
# MV Agusta F3 AMG
# Yamaha Janus 2019
# Yamaha NVX 155
# Yamaha Exciter 135
# Honda MSX 125
# Honda Wave Alpha 100
# Honda Winner X 150
# Honda Wave Alpha RSX
# Honda Super Cub 50
# Yamaha Janus 2019
# Piaggio Liberty 125
# Yamaha Mio Ultimo
# Yamaha Freego 125
# Honda Air Blade 125 FI
# Honda Wave Alpha RSX
# Yamaha Exciter 150 RC
# Honda Dream 100
# Honda LEAD 125 FI
# Piaggio Vespa 125
# Piaggio Medley 125
# Suzuki GD 110
# Honda Future 125
# Yamaha R15 V2 150
# Kymco K-Pipe 50
# Honda PCX 125
# Honda LEAD 125 FI
# Yamaha YP Majesty  250
# Yamaha Exciter 150
# Yamaha R15 V3
# Honda Wave Alpha 100
# Yamaha Janus 2019
# Piaggio Zip 100
# Honda Air Blade 125 FI
# Honda Air Blade 110 FI
# Bosscity KPR 125
# Yamaha Freego 125
# Yamaha Janus 2019
# Piaggio Liberty 125
# Suzuki GZ 150A
# Piaggio Liberty 125
# Honda Vision 110
# Honda Wave Alpha 100
# Suzuki GZ 125
# Honda Vario 150
# Suzuki GD 110
# Yamaha Janus 2019
# Yamaha NVX 125
# Suzuki GSX R150
# Honda Wave Alpha RSX 110 Fi
# Honda LEAD 110
# Honda LEAD 125 FI
# Suzuki GZ 150A
# Yamaha FZ S
# Honda Click 110
# Honda Wave Alpha 100
# Honda MSX 125
# Yamaha Sirius 110
# MV Agusta F3 675
# Yamaha Cuxi 100
# Yamaha R15 V2 150
# Honda PCX 125
# SYM Elite 50
# SYM Shark 125
# Honda Air Blade 150 Fi
# Yamaha MT 15
# Kymco K-Pipe 50
# Honda MSX 125
# Honda CBR 150 R
# Honda CBF 190
# Honda Rebel 150
# Benelli TNT 125
# Yamaha Acruzo Deluxe 2016
# Yamaha Exciter 150 RC
# Honda Wave Alpha 110
# Honda Vision 110
# Yamaha Grande Blue Core
# Honda Click 110
# Honda Dream 50 R
# Honda Wave Alpha 100
# Honda Air Blade 110 FI
# Honda PCX 125
# Suzuki Raider R 150 FI
# Honda Air Blade 125 FI
# Honda Vision 110
# Honda Wave Alpha 110
# Yamaha Grande Blue Core
# Honda Wave Alpha 100
# Honda Air Blade 125 FI
# Yamaha Luvias Fi
# Yamaha NVX 155 ABS
# Yamaha Sirius 110
# Yamaha Sirius Fi
# Yamaha Luvias Fi
# Honda Wave Alpha 110i
# Honda Air Blade 125 FI
# Honda Wave Alpha 110
# Honda Air Blade 125 FI
# Honda Future 125
# Yamaha R15 V3
# Yamaha Exciter 135
# Yamaha R15 V2 150
# Honda Vario 150
# Yamaha Nozza Grande 125
# Honda PS 150i
# Suzuki Raider R 150 FI
# Honda Air Blade 110 FI
# Nioshima Vespa S
# Honda Air Blade 110
# Honda SH 125i
# Honda Vario 150
# Piaggio Zip 100
# Honda Rebel 300
# Piaggio Vespa LX
# Honda Air Blade 125 FI
# Benelli BN 302
# Piaggio Liberty 125
# Ducati Mini 110
# Yamaha TFX 150
# Honda Vision 110
# Honda Vision 110
# Honda LEAD 125 FI
# Piaggio Vespa LX
# Suzuki Hayate 125 FI
# Piaggio Liberty 125
# Honda LEAD 125 FI
# Honda Winner X 150
# Honda Air Blade 125 FI
# Honda Wave Alpha 110i
# Yamaha Janus 2019
# Yamaha Nouvo 4 135
# Yamaha Sirius Fi
# Honda Wave Alpha RSX 110 Fi
# SYM Shark 170
# Honda Wave Alpha 110
# Honda Wave Alpha 110
# Yamaha Nouvo FI SX
# Honda Air Blade 125 FI
# Honda Wave Alpha RSX 110 Fi
# Yamaha MT 15
# Honda Air Blade 125 FI
# Piaggio Liberty 125
# Honda Wave Alpha RSX
# Yamaha Janus 2019
# Honda Vision 110
# Honda Crea Giorno
# Honda Vision 110
# Suzuki Impulse 125 Fi
# Honda Winner X 150
# Honda Click 110
# Honda Crea Giorno
# Honda Vision 110
# Honda Air Blade 150 Fi
# Yamaha R15 V3 1055
# Yamaha R15 V3 1055
# SYM Elite 50
# Honda SH 125
# Yamaha TFX 150
# Piaggio Vespa LX
# Honda Wave Alpha 110
# Honda Wave Alpha 50
# Piaggio Vespa S125 i.e
# Kymco K-Pipe 50
# Honda SH Mode 125
# Honda LEAD 110
# Honda SH 125
# Honda Vario 150
# Suzuki Satria F150 Fi
# Honda LEAD 125 FI
# Yamaha Exciter 135
# Piaggio Vespa LX
# Piaggio Vespa Sprint
# Honda Wave Alpha 100
# Honda Winner 150
# Honda Rebel 300 ABS
# Yamaha Exciter 150 RC
# Honda PCX 125
# Honda Wave Alpha RSX
# Yamaha BWs 125
# Yamaha Exciter 135
# Yamaha Janus 2019
# Yamaha R15 V3 1055
# Honda Future 125
# Honda Wave Alpha 100
# Honda Air Blade 110 FI
# Honda Air Blade 110
# Honda Air Blade 150 Fi
# Honda Wave S 110
# Brixton BX 150 X
# Honda MSX 125
# Honda Air Blade 110
# Ducati Mini 110
# Yamaha TFX 150

# %%
total_vehicleinfo
# Out:
# [{'infoid': 1,
#   'Vehicle_name': 'Yamaha Latte',
#   'Odometer': 10000,
#   'License_plate': None,
#   'Cubic_power': '125cc',
#   'Manufacture_year': 202011,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 1711,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 2,
#   'Vehicle_name': 'SYM Angel 110',
#   'Odometer': 100000,
#   'License_plate': None,
#   'Cubic_power': '110',
#   'Manufacture_year': 200504,
#   'ID_VehicleBrand': 35,
#   'ID_VehicleLineup': 438,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 13},
#  {'infoid': 3,
#   'Vehicle_name': 'Harley Davidson Forty-Eight Special',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '1200',
#   'Manufacture_year': 201912,
#   'ID_VehicleBrand': 13,
#   'ID_VehicleLineup': 115,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 3},
#  {'infoid': 4,
#   'Vehicle_name': 'Harley Davidson Street 750',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '750',
#   'Manufacture_year': 201503,
#   'ID_VehicleBrand': 13,
#   'ID_VehicleLineup': 1231,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 3},
#  {'infoid': 5,
#   'Vehicle_name': 'Suzuki GZ 150A',
#   'Odometer': 23000,
#   'License_plate': '60F2-61723',
#   'Cubic_power': '149',
#   'Manufacture_year': 201712,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 414,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 6,
#   'Vehicle_name': 'Honda SH 150',
#   'Odometer': 51000,
#   'License_plate': '29C1-76877',
#   'Cubic_power': '153',
#   'Manufacture_year': 200811,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 167,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 7,
#   'Vehicle_name': 'Honda SH 150',
#   'Odometer': 1000,
#   'License_plate': '89B2-02024',
#   'Cubic_power': '153',
#   'Manufacture_year': 202112,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 167,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 8,
#   'Vehicle_name': 'Honda Air Blade 125 FI',
#   'Odometer': 20000,
#   'License_plate': '17B3-12367',
#   'Cubic_power': '125',
#   'Manufacture_year': 201412,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 7},
#  {'infoid': 9,
#   'Vehicle_name': 'Honda Wave Alpha 100',
#   'Odometer': 50000,
#   'License_plate': '16K6-9854',
#   'Cubic_power': '97.1',
#   'Manufacture_year': 200612,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 10,
#   'Vehicle_name': 'Honda Future 125',
#   'Odometer': 91000,
#   'License_plate': '17B1-89606',
#   'Cubic_power': '124,9',
#   'Manufacture_year': 201211,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 198,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 11,
#   'Vehicle_name': 'Honda Vision NSC110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201912,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 135,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 12,
#   'Vehicle_name': 'Piaggio Liberty 125',
#   'Odometer': 30000,
#   'License_plate': None,
#   'Cubic_power': '124cc',
#   'Manufacture_year': 201206,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 355,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 13,
#   'Vehicle_name': 'Piaggio Zip 100',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '96.2',
#   'Manufacture_year': 201407,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 348,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 14,
#   'Vehicle_name': 'Honda Winner X 150',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '150',
#   'Manufacture_year': 202106,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1076,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 15,
#   'Vehicle_name': 'Honda Future 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124,9',
#   'Manufacture_year': 201912,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 198,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 7},
#  {'infoid': 16,
#   'Vehicle_name': 'Piaggio Liberty 125',
#   'Odometer': 30000,
#   'License_plate': None,
#   'Cubic_power': '124cc',
#   'Manufacture_year': 201106,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 355,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 17,
#   'Vehicle_name': 'Honda Vision 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201412,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 135,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 7},
#  {'infoid': 18,
#   'Vehicle_name': 'Honda Air Blade 110 FI',
#   'Odometer': 30000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201006,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 19,
#   'Vehicle_name': 'Honda Air Blade 110 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201112,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 20,
#   'Vehicle_name': 'Honda Air Blade 110 FI',
#   'Odometer': 30000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201205,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 5},
#  {'infoid': 21,
#   'Vehicle_name': 'Honda Air Blade 125 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201812,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 22,
#   'Vehicle_name': 'Honda Winner 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149',
#   'Manufacture_year': 201812,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 180,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 23,
#   'Vehicle_name': 'Honda Vision 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201412,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 135,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 2},
#  {'infoid': 24,
#   'Vehicle_name': 'Yamaha Exciter 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.7',
#   'Manufacture_year': 201812,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 13},
#  {'infoid': 25,
#   'Vehicle_name': 'Yamaha Exciter 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.7',
#   'Manufacture_year': 201712,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 26,
#   'Vehicle_name': 'Piaggio Liberty 125',
#   'Odometer': 30000,
#   'License_plate': None,
#   'Cubic_power': '124cc',
#   'Manufacture_year': 201111,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 355,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 27,
#   'Vehicle_name': 'Honda Vision 110',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201611,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 135,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 28,
#   'Vehicle_name': 'Yamaha Exciter 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.7',
#   'Manufacture_year': 201712,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 29,
#   'Vehicle_name': 'Honda Air Blade 110 FI',
#   'Odometer': 30000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201111,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 30,
#   'Vehicle_name': 'Yamaha Exciter 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.7',
#   'Manufacture_year': 201712,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 5},
#  {'infoid': 31,
#   'Vehicle_name': 'Yamaha Exciter 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.7',
#   'Manufacture_year': 201812,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 32,
#   'Vehicle_name': 'Yamaha Janus 2019',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201912,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 525,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 16},
#  {'infoid': 33,
#   'Vehicle_name': 'Honda Air Blade 110 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201112,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 34,
#   'Vehicle_name': 'SYM Elizabeth Standard',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '111.1',
#   'Manufacture_year': 201501,
#   'ID_VehicleBrand': 35,
#   'ID_VehicleLineup': 446,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 35,
#   'Vehicle_name': 'Honda Super Cub 50',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '49',
#   'Manufacture_year': 202105,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 133,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 36,
#   'Vehicle_name': 'Honda Vision 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 202107,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 135,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 13},
#  {'infoid': 37,
#   'Vehicle_name': 'Ducati Mini 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '110',
#   'Manufacture_year': 202109,
#   'ID_VehicleBrand': 9,
#   'ID_VehicleLineup': 1075,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 3},
#  {'infoid': 38,
#   'Vehicle_name': 'Yamaha Exciter 150 RC',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.7',
#   'Manufacture_year': 202112,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 39,
#   'Vehicle_name': 'Honda LEAD 125 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202001,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 145,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 40,
#   'Vehicle_name': 'SYM Shark 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '150',
#   'Manufacture_year': 201802,
#   'ID_VehicleBrand': 35,
#   'ID_VehicleLineup': 449,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 7},
#  {'infoid': 41,
#   'Vehicle_name': 'Yamaha Sirius Fi',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '115',
#   'Manufacture_year': 202005,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 512,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 42,
#   'Vehicle_name': 'Brixton Scrambler 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '150',
#   'Manufacture_year': 202112,
#   'ID_VehicleBrand': 5,
#   'ID_VehicleLineup': 1203,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 7},
#  {'infoid': 43,
#   'Vehicle_name': 'Honda SH Mode 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201808,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 167,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 44,
#   'Vehicle_name': 'Yamaha Jupiter FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '114',
#   'Manufacture_year': 202109,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 528,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 45,
#   'Vehicle_name': 'Ducati Monster 795',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '803',
#   'Manufacture_year': 202005,
#   'ID_VehicleBrand': 9,
#   'ID_VehicleLineup': 86,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 5},
#  {'infoid': 46,
#   'Vehicle_name': 'Yamaha Exciter 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.7',
#   'Manufacture_year': 202201,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 13},
#  {'infoid': 47,
#   'Vehicle_name': 'Yamaha NVX 155 ABS',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '155',
#   'Manufacture_year': 201808,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 542,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 13},
#  {'infoid': 48,
#   'Vehicle_name': 'Suzuki Husky 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202101,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 419,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 49,
#   'Vehicle_name': 'Honda Wave Alpha 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '109.16',
#   'Manufacture_year': 202112,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 50,
#   'Vehicle_name': 'Honda Vision 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 202005,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 135,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 14},
#  {'infoid': 51,
#   'Vehicle_name': 'Suzuki GD 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '112.8',
#   'Manufacture_year': 202202,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 408,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 52,
#   'Vehicle_name': 'Yamaha NVX 155 ABS',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '155',
#   'Manufacture_year': 202005,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 542,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 15},
#  {'infoid': 53,
#   'Vehicle_name': 'Yamaha TFX 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.8',
#   'Manufacture_year': 202109,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 539,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 4},
#  {'infoid': 54,
#   'Vehicle_name': 'Honda Wave Alpha 110',
#   'Odometer': 30000,
#   'License_plate': None,
#   'Cubic_power': '109.16',
#   'Manufacture_year': 200912,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 14},
#  {'infoid': 55,
#   'Vehicle_name': 'Piaggio Vespa LX',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.5',
#   'Manufacture_year': 201901,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 349,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 56,
#   'Vehicle_name': 'Yamaha Jupiter FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '114',
#   'Manufacture_year': 201601,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 528,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 57,
#   'Vehicle_name': 'Piaggio Vespa S125 i.e',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.5',
#   'Manufacture_year': 201401,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 349,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 58,
#   'Vehicle_name': 'Yamaha NVX 155 ABS',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '155',
#   'Manufacture_year': 201907,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 542,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 59,
#   'Vehicle_name': 'Honda Vision 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201408,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 135,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 8},
#  {'infoid': 60,
#   'Vehicle_name': 'Piaggio Zip 100',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '96.2',
#   'Manufacture_year': 201805,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 348,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 61,
#   'Vehicle_name': 'MV Agusta Dragster 800',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '798',
#   'Manufacture_year': 202112,
#   'ID_VehicleBrand': 26,
#   'ID_VehicleLineup': 320,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 10},
#  {'infoid': 62,
#   'Vehicle_name': 'Suzuki GZ 150A',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149',
#   'Manufacture_year': 202101,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 414,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 63,
#   'Vehicle_name': 'Honda LEAD 125 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201911,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 145,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 64,
#   'Vehicle_name': 'Honda Future 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124,9',
#   'Manufacture_year': 201808,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 198,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 65,
#   'Vehicle_name': 'MV Agusta F3 AMG',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '798',
#   'Manufacture_year': 202109,
#   'ID_VehicleBrand': 26,
#   'ID_VehicleLineup': 317,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 10},
#  {'infoid': 66,
#   'Vehicle_name': 'Yamaha Janus 2019',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202202,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 525,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 11},
#  {'infoid': 67,
#   'Vehicle_name': 'Yamaha NVX 155',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '155',
#   'Manufacture_year': 201804,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 542,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 16},
#  {'infoid': 68,
#   'Vehicle_name': 'Yamaha Exciter 135',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '135',
#   'Manufacture_year': 201501,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 8},
#  {'infoid': 69,
#   'Vehicle_name': 'Honda MSX 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.9',
#   'Manufacture_year': 202005,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 165,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 70,
#   'Vehicle_name': 'Honda Wave Alpha 100',
#   'Odometer': 10000,
#   'License_plate': None,
#   'Cubic_power': '97.1',
#   'Manufacture_year': 201401,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 71,
#   'Vehicle_name': 'Honda Winner X 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '150',
#   'Manufacture_year': 202208,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1076,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 72,
#   'Vehicle_name': 'Honda Wave Alpha RSX',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '110',
#   'Manufacture_year': 201609,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 73,
#   'Vehicle_name': 'Honda Super Cub 50',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '49',
#   'Manufacture_year': 202101,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 133,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 74,
#   'Vehicle_name': 'Yamaha Janus 2019',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201905,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 525,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 75,
#   'Vehicle_name': 'Piaggio Liberty 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124cc',
#   'Manufacture_year': 201607,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 355,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 76,
#   'Vehicle_name': 'Yamaha Mio Ultimo',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '115',
#   'Manufacture_year': 201006,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 516,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 77,
#   'Vehicle_name': 'Yamaha Freego 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125cc',
#   'Manufacture_year': 202202,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 1600,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 78,
#   'Vehicle_name': 'Honda Air Blade 125 FI',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201312,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 79,
#   'Vehicle_name': 'Honda Wave Alpha RSX',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '110',
#   'Manufacture_year': 202005,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 80,
#   'Vehicle_name': 'Yamaha Exciter 150 RC',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.7',
#   'Manufacture_year': 202001,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 81,
#   'Vehicle_name': 'Honda Dream 100',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '100',
#   'Manufacture_year': 200708,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 132,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 7},
#  {'infoid': 82,
#   'Vehicle_name': 'Honda LEAD 125 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201908,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 145,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 83,
#   'Vehicle_name': 'Piaggio Vespa 125',
#   'Odometer': 10000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201601,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 349,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 13},
#  {'infoid': 84,
#   'Vehicle_name': 'Piaggio Medley 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.7',
#   'Manufacture_year': 201806,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 352,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 85,
#   'Vehicle_name': 'Suzuki GD 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '112.8',
#   'Manufacture_year': 202005,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 408,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 86,
#   'Vehicle_name': 'Honda Future 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124,9',
#   'Manufacture_year': 202109,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 198,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 87,
#   'Vehicle_name': 'Yamaha R15 V2 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': None,
#   'Manufacture_year': 201901,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 1077,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 14},
#  {'infoid': 88,
#   'Vehicle_name': 'Kymco K-Pipe 50',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '49',
#   'Manufacture_year': 202105,
#   'ID_VehicleBrand': 21,
#   'ID_VehicleLineup': 252,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 89,
#   'Vehicle_name': 'Honda PCX 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.9',
#   'Manufacture_year': 201701,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 166,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 7},
#  {'infoid': 90,
#   'Vehicle_name': 'Honda LEAD 125 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202005,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 145,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 8},
#  {'infoid': 91,
#   'Vehicle_name': 'Yamaha YP Majesty  250',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '249',
#   'Manufacture_year': 202012,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 544,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 1},
#  {'infoid': 92,
#   'Vehicle_name': 'Yamaha Exciter 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.7',
#   'Manufacture_year': 201901,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 93,
#   'Vehicle_name': 'Yamaha R15 V3',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '155',
#   'Manufacture_year': 202001,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 540,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 94,
#   'Vehicle_name': 'Honda Wave Alpha 100',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '97.1',
#   'Manufacture_year': 201608,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 14},
#  {'infoid': 95,
#   'Vehicle_name': 'Yamaha Janus 2019',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202107,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 525,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 96,
#   'Vehicle_name': 'Piaggio Zip 100',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '96.2',
#   'Manufacture_year': 201704,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 348,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 97,
#   'Vehicle_name': 'Honda Air Blade 125 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202201,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 98,
#   'Vehicle_name': 'Honda Air Blade 110 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201111,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 99,
#   'Vehicle_name': 'Bosscity KPR 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125cc',
#   'Manufacture_year': 201801,
#   'ID_VehicleBrand': 117,
#   'ID_VehicleLineup': 1602,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 100,
#   'Vehicle_name': 'Yamaha Freego 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125cc',
#   'Manufacture_year': 201911,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 1600,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 14},
#  {'infoid': 101,
#   'Vehicle_name': 'Yamaha Janus 2019',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202108,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 525,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 102,
#   'Vehicle_name': 'Piaggio Liberty 125',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '124cc',
#   'Manufacture_year': 201201,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 355,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 103,
#   'Vehicle_name': 'Suzuki GZ 150A',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149',
#   'Manufacture_year': 202007,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 414,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 104,
#   'Vehicle_name': 'Piaggio Liberty 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124cc',
#   'Manufacture_year': 201301,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 355,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 105,
#   'Vehicle_name': 'Honda Vision 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201501,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 135,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 106,
#   'Vehicle_name': 'Honda Wave Alpha 100',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '97.1',
#   'Manufacture_year': 201908,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 107,
#   'Vehicle_name': 'Suzuki GZ 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124',
#   'Manufacture_year': 201604,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 414,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 108,
#   'Vehicle_name': 'Honda Vario 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '150',
#   'Manufacture_year': 202108,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 178,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 109,
#   'Vehicle_name': 'Suzuki GD 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '112.8',
#   'Manufacture_year': 202101,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 408,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 110,
#   'Vehicle_name': 'Yamaha Janus 2019',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202001,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 525,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 11},
#  {'infoid': 111,
#   'Vehicle_name': 'Yamaha NVX 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202101,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 542,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 112,
#   'Vehicle_name': 'Suzuki GSX R150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '147.3',
#   'Manufacture_year': 201912,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 431,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 113,
#   'Vehicle_name': 'Honda Wave Alpha RSX 110 Fi',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '110',
#   'Manufacture_year': 201508,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 114,
#   'Vehicle_name': 'Honda LEAD 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '107',
#   'Manufacture_year': 201405,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 145,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 115,
#   'Vehicle_name': 'Honda LEAD 125 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202201,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 145,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 2},
#  {'infoid': 116,
#   'Vehicle_name': 'Suzuki GZ 150A',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149',
#   'Manufacture_year': 202101,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 414,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 117,
#   'Vehicle_name': 'Yamaha FZ S',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '153',
#   'Manufacture_year': 201811,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 537,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 118,
#   'Vehicle_name': 'Honda Click 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '110',
#   'Manufacture_year': 201008,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 163,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 119,
#   'Vehicle_name': 'Honda Wave Alpha 100',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '97.1',
#   'Manufacture_year': 201101,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 120,
#   'Vehicle_name': 'Honda MSX 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.9',
#   'Manufacture_year': 201801,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 165,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 121,
#   'Vehicle_name': 'Yamaha Sirius 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '110.3',
#   'Manufacture_year': 201801,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 512,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 122,
#   'Vehicle_name': 'MV Agusta F3 675',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '675',
#   'Manufacture_year': 202010,
#   'ID_VehicleBrand': 26,
#   'ID_VehicleLineup': 317,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 3},
#  {'infoid': 123,
#   'Vehicle_name': 'Yamaha Cuxi 100',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '102',
#   'Manufacture_year': 201808,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 513,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 124,
#   'Vehicle_name': 'Yamaha R15 V2 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': None,
#   'Manufacture_year': 201801,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 1077,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 10},
#  {'infoid': 125,
#   'Vehicle_name': 'Honda PCX 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.9',
#   'Manufacture_year': 201601,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 166,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 126,
#   'Vehicle_name': 'SYM Elite 50',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '49.5',
#   'Manufacture_year': 202106,
#   'ID_VehicleBrand': 35,
#   'ID_VehicleLineup': 445,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 127,
#   'Vehicle_name': 'SYM Shark 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201401,
#   'ID_VehicleBrand': 35,
#   'ID_VehicleLineup': 449,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 128,
#   'Vehicle_name': 'Honda Air Blade 150 Fi',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '150',
#   'Manufacture_year': 202107,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 13},
#  {'infoid': 129,
#   'Vehicle_name': 'Yamaha MT 15',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '155',
#   'Manufacture_year': 202112,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 531,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 130,
#   'Vehicle_name': 'Kymco K-Pipe 50',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '49',
#   'Manufacture_year': 202007,
#   'ID_VehicleBrand': 21,
#   'ID_VehicleLineup': 252,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 13},
#  {'infoid': 131,
#   'Vehicle_name': 'Honda MSX 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.9',
#   'Manufacture_year': 201801,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 165,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 132,
#   'Vehicle_name': 'Honda CBR 150 R',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.4',
#   'Manufacture_year': 202109,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 168,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 133,
#   'Vehicle_name': 'Honda CBF 190',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '190',
#   'Manufacture_year': 202105,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 193,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 10},
#  {'infoid': 134,
#   'Vehicle_name': 'Honda Rebel 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '150cc',
#   'Manufacture_year': 201601,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 181,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 135,
#   'Vehicle_name': 'Benelli TNT 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124,8',
#   'Manufacture_year': 202001,
#   'ID_VehicleBrand': 3,
#   'ID_VehicleLineup': 15,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 136,
#   'Vehicle_name': 'Yamaha Acruzo Deluxe 2016',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202107,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 522,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 137,
#   'Vehicle_name': 'Yamaha Exciter 150 RC',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.7',
#   'Manufacture_year': 201912,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 138,
#   'Vehicle_name': 'Honda Wave Alpha 110',
#   'Odometer': 10000,
#   'License_plate': None,
#   'Cubic_power': '109.16',
#   'Manufacture_year': 201901,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 139,
#   'Vehicle_name': 'Honda Vision 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201405,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 135,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 7},
#  {'infoid': 140,
#   'Vehicle_name': 'Yamaha Grande Blue Core',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124',
#   'Manufacture_year': 202201,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 520,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 14},
#  {'infoid': 141,
#   'Vehicle_name': 'Honda Click 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '110',
#   'Manufacture_year': 201501,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 163,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 7},
#  {'infoid': 142,
#   'Vehicle_name': 'Honda Dream 50 R',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '49',
#   'Manufacture_year': 202201,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 132,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 143,
#   'Vehicle_name': 'Honda Wave Alpha 100',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '97.1',
#   'Manufacture_year': 201406,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 144,
#   'Vehicle_name': 'Honda Air Blade 110 FI',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201108,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 145,
#   'Vehicle_name': 'Honda PCX 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.9',
#   'Manufacture_year': 201401,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 166,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 146,
#   'Vehicle_name': 'Suzuki Raider R 150 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '147.3',
#   'Manufacture_year': 202112,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 402,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 147,
#   'Vehicle_name': 'Honda Air Blade 125 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201701,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 148,
#   'Vehicle_name': 'Honda Vision 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 202107,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 135,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 15},
#  {'infoid': 149,
#   'Vehicle_name': 'Honda Wave Alpha 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '109.16',
#   'Manufacture_year': 201206,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 13},
#  {'infoid': 150,
#   'Vehicle_name': 'Yamaha Grande Blue Core',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124',
#   'Manufacture_year': 201901,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 520,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 2},
#  {'infoid': 151,
#   'Vehicle_name': 'Honda Wave Alpha 100',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '97.1',
#   'Manufacture_year': 201002,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 152,
#   'Vehicle_name': 'Honda Air Blade 125 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201401,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 153,
#   'Vehicle_name': 'Yamaha Luvias Fi',
#   'Odometer': 30000,
#   'License_plate': None,
#   'Cubic_power': '124.9',
#   'Manufacture_year': 201105,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 521,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 7},
#  {'infoid': 154,
#   'Vehicle_name': 'Yamaha NVX 155 ABS',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '155',
#   'Manufacture_year': 202005,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 542,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 15},
#  {'infoid': 155,
#   'Vehicle_name': 'Yamaha Sirius 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '110.3',
#   'Manufacture_year': 201801,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 512,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 156,
#   'Vehicle_name': 'Yamaha Sirius Fi',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '115',
#   'Manufacture_year': 201909,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 512,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 14},
#  {'infoid': 157,
#   'Vehicle_name': 'Yamaha Luvias Fi',
#   'Odometer': 30000,
#   'License_plate': None,
#   'Cubic_power': '124.9',
#   'Manufacture_year': 201003,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 521,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 158,
#   'Vehicle_name': 'Honda Wave Alpha 110i',
#   'Odometer': 10000,
#   'License_plate': None,
#   'Cubic_power': '109.1',
#   'Manufacture_year': 201801,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 159,
#   'Vehicle_name': 'Honda Air Blade 125 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201605,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 8},
#  {'infoid': 160,
#   'Vehicle_name': 'Honda Wave Alpha 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '109.16',
#   'Manufacture_year': 201001,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 161,
#   'Vehicle_name': 'Honda Air Blade 125 FI',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201503,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 162,
#   'Vehicle_name': 'Honda Future 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124,9',
#   'Manufacture_year': 202009,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 198,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 7},
#  {'infoid': 163,
#   'Vehicle_name': 'Yamaha R15 V3',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '155',
#   'Manufacture_year': 202006,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 540,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 164,
#   'Vehicle_name': 'Yamaha Exciter 135',
#   'Odometer': 30000,
#   'License_plate': None,
#   'Cubic_power': '135',
#   'Manufacture_year': 201210,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 14},
#  {'infoid': 165,
#   'Vehicle_name': 'Yamaha R15 V2 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': None,
#   'Manufacture_year': 201701,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 1077,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 15},
#  {'infoid': 166,
#   'Vehicle_name': 'Honda Vario 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '150',
#   'Manufacture_year': 202111,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 178,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 167,
#   'Vehicle_name': 'Yamaha Nozza Grande 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '113',
#   'Manufacture_year': 201908,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 514,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 2},
#  {'infoid': 168,
#   'Vehicle_name': 'Honda PS 150i',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '123',
#   'Manufacture_year': 201101,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 156,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 13},
#  {'infoid': 169,
#   'Vehicle_name': 'Suzuki Raider R 150 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '147.3',
#   'Manufacture_year': 201910,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 402,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 8},
#  {'infoid': 170,
#   'Vehicle_name': 'Honda Air Blade 110 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201609,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 171,
#   'Vehicle_name': 'Nioshima Vespa S',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '1500W',
#   'Manufacture_year': 202003,
#   'ID_VehicleBrand': 119,
#   'ID_VehicleLineup': 1614,
#   'Condition': 'used',
#   'ID_VehicleType': '4',
#   'ID_Color': 3},
#  {'infoid': 172,
#   'Vehicle_name': 'Honda Air Blade 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201401,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 173,
#   'Vehicle_name': 'Honda SH 125i',
#   'Odometer': 10000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201711,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 167,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 5},
#  {'infoid': 174,
#   'Vehicle_name': 'Honda Vario 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '150',
#   'Manufacture_year': 202011,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 178,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 16},
#  {'infoid': 175,
#   'Vehicle_name': 'Piaggio Zip 100',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '96.2',
#   'Manufacture_year': 202011,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 348,
# ...
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 199,
#   'Vehicle_name': 'Honda Wave Alpha 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '109.16',
#   'Manufacture_year': 201907,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 200,
#   'Vehicle_name': 'Yamaha Nouvo FI SX',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '124.9',
#   'Manufacture_year': 201507,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 527,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 201,
#   'Vehicle_name': 'Honda Air Blade 125 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202101,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 202,
#   'Vehicle_name': 'Honda Wave Alpha RSX 110 Fi',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '110',
#   'Manufacture_year': 202206,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 203,
#   'Vehicle_name': 'Yamaha MT 15',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '155',
#   'Manufacture_year': 202107,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 531,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 204,
#   'Vehicle_name': 'Honda Air Blade 125 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202202,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 5},
#  {'infoid': 205,
#   'Vehicle_name': 'Piaggio Liberty 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124cc',
#   'Manufacture_year': 201501,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 355,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 5},
#  {'infoid': 206,
#   'Vehicle_name': 'Honda Wave Alpha RSX',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '110',
#   'Manufacture_year': 201612,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 207,
#   'Vehicle_name': 'Yamaha Janus 2019',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202112,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 525,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 5},
#  {'infoid': 208,
#   'Vehicle_name': 'Honda Vision 110',
#   'Odometer': 10000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201708,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 135,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 209,
#   'Vehicle_name': 'Honda Crea Giorno',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '49',
#   'Manufacture_year': 202102,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 134,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 210,
#   'Vehicle_name': 'Honda Vision 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 202001,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 135,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 14},
#  {'infoid': 211,
#   'Vehicle_name': 'Suzuki Impulse 125 Fi',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124',
#   'Manufacture_year': 201906,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 423,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 212,
#   'Vehicle_name': 'Honda Winner X 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '150',
#   'Manufacture_year': 202107,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1076,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 213,
#   'Vehicle_name': 'Honda Click 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '110',
#   'Manufacture_year': 201512,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 163,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 214,
#   'Vehicle_name': 'Honda Crea Giorno',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '49',
#   'Manufacture_year': 201904,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 134,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 215,
#   'Vehicle_name': 'Honda Vision 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 202201,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 135,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 15},
#  {'infoid': 216,
#   'Vehicle_name': 'Honda Air Blade 150 Fi',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '150',
#   'Manufacture_year': 202202,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 217,
#   'Vehicle_name': 'Yamaha R15 V3 1055',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': None,
#   'Manufacture_year': 202101,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 1078,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 13},
#  {'infoid': 218,
#   'Vehicle_name': 'Yamaha R15 V3 1055',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': None,
#   'Manufacture_year': 201906,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 1078,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 15},
#  {'infoid': 219,
#   'Vehicle_name': 'SYM Elite 50',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '49.5',
#   'Manufacture_year': 202110,
#   'ID_VehicleBrand': 35,
#   'ID_VehicleLineup': 445,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 220,
#   'Vehicle_name': 'Honda SH 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.9',
#   'Manufacture_year': 201608,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 167,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 221,
#   'Vehicle_name': 'Yamaha TFX 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.8',
#   'Manufacture_year': 202107,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 539,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 4},
#  {'infoid': 222,
#   'Vehicle_name': 'Piaggio Vespa LX',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.5',
#   'Manufacture_year': 201601,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 349,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 14},
#  {'infoid': 223,
#   'Vehicle_name': 'Honda Wave Alpha 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '109.16',
#   'Manufacture_year': 200601,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 224,
#   'Vehicle_name': 'Honda Wave Alpha 50',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '100',
#   'Manufacture_year': 202107,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 225,
#   'Vehicle_name': 'Piaggio Vespa S125 i.e',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.5',
#   'Manufacture_year': 201708,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 349,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 226,
#   'Vehicle_name': 'Kymco K-Pipe 50',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '49',
#   'Manufacture_year': 202108,
#   'ID_VehicleBrand': 21,
#   'ID_VehicleLineup': 252,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 227,
#   'Vehicle_name': 'Honda SH Mode 125',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201706,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 167,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 228,
#   'Vehicle_name': 'Honda LEAD 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '107',
#   'Manufacture_year': 201601,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 145,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 7},
#  {'infoid': 229,
#   'Vehicle_name': 'Honda SH 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.9',
#   'Manufacture_year': 201601,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 167,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 230,
#   'Vehicle_name': 'Honda Vario 150',
#   'Odometer': 10000,
#   'License_plate': None,
#   'Cubic_power': '150',
#   'Manufacture_year': 201808,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 178,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 231,
#   'Vehicle_name': 'Suzuki Satria F150 Fi',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '147.3',
#   'Manufacture_year': 202107,
#   'ID_VehicleBrand': 34,
#   'ID_VehicleLineup': 432,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 232,
#   'Vehicle_name': 'Honda LEAD 125 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202105,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 145,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 2},
#  {'infoid': 233,
#   'Vehicle_name': 'Yamaha Exciter 135',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '135',
#   'Manufacture_year': 201406,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 234,
#   'Vehicle_name': 'Piaggio Vespa LX',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.5',
#   'Manufacture_year': 201901,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 349,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 14},
#  {'infoid': 235,
#   'Vehicle_name': 'Piaggio Vespa Sprint',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.5',
#   'Manufacture_year': 201801,
#   'ID_VehicleBrand': 29,
#   'ID_VehicleLineup': 349,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 15},
#  {'infoid': 236,
#   'Vehicle_name': 'Honda Wave Alpha 100',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '97.1',
#   'Manufacture_year': 201608,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 7},
#  {'infoid': 237,
#   'Vehicle_name': 'Honda Winner 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149',
#   'Manufacture_year': 201912,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 180,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 5},
#  {'infoid': 238,
#   'Vehicle_name': 'Honda Rebel 300 ABS',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '286',
#   'Manufacture_year': 202107,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 181,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 10},
#  {'infoid': 239,
#   'Vehicle_name': 'Yamaha Exciter 150 RC',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.7',
#   'Manufacture_year': 202106,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 240,
#   'Vehicle_name': 'Honda PCX 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.9',
#   'Manufacture_year': 201601,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 166,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 7},
#  {'infoid': 241,
#   'Vehicle_name': 'Honda Wave Alpha RSX',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '110',
#   'Manufacture_year': 202105,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 14},
#  {'infoid': 242,
#   'Vehicle_name': 'Yamaha BWs 125',
#   'Odometer': 20000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 201306,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 524,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 243,
#   'Vehicle_name': 'Yamaha Exciter 135',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '135',
#   'Manufacture_year': 201609,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 535,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 15},
#  {'infoid': 244,
#   'Vehicle_name': 'Yamaha Janus 2019',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '125',
#   'Manufacture_year': 202011,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 525,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 15},
#  {'infoid': 245,
#   'Vehicle_name': 'Yamaha R15 V3 1055',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': None,
#   'Manufacture_year': 202107,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 1078,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 3},
#  {'infoid': 246,
#   'Vehicle_name': 'Honda Future 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124,9',
#   'Manufacture_year': 201801,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 198,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 247,
#   'Vehicle_name': 'Honda Wave Alpha 100',
#   'Odometer': 10000,
#   'License_plate': None,
#   'Cubic_power': '97.1',
#   'Manufacture_year': 201504,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1055,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 1},
#  {'infoid': 248,
#   'Vehicle_name': 'Honda Air Blade 110 FI',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201406,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 7},
#  {'infoid': 249,
#   'Vehicle_name': 'Honda Air Blade 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201501,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 1},
#  {'infoid': 250,
#   'Vehicle_name': 'Honda Air Blade 150 Fi',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '150',
#   'Manufacture_year': 202106,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 10},
#  {'infoid': 251,
#   'Vehicle_name': 'Honda Wave S 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '110cc',
#   'Manufacture_year': 201601,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 1700,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 10},
#  {'infoid': 252,
#   'Vehicle_name': 'Brixton BX 150 X',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '150',
#   'Manufacture_year': 202107,
#   'ID_VehicleBrand': 5,
#   'ID_VehicleLineup': 31,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 3},
#  {'infoid': 253,
#   'Vehicle_name': 'Honda MSX 125',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '124.9',
#   'Manufacture_year': 202112,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 165,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 3},
#  {'infoid': 254,
#   'Vehicle_name': 'Honda Air Blade 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '108',
#   'Manufacture_year': 201001,
#   'ID_VehicleBrand': 15,
#   'ID_VehicleLineup': 148,
#   'Condition': 'used',
#   'ID_VehicleType': '1',
#   'ID_Color': 3},
#  {'infoid': 255,
#   'Vehicle_name': 'Ducati Mini 110',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '110',
#   'Manufacture_year': 202102,
#   'ID_VehicleBrand': 9,
#   'ID_VehicleLineup': 1075,
#   'Condition': 'used',
#   'ID_VehicleType': '3',
#   'ID_Color': 3},
#  {'infoid': 256,
#   'Vehicle_name': 'Yamaha TFX 150',
#   'Odometer': 5000,
#   'License_plate': None,
#   'Cubic_power': '149.8',
#   'Manufacture_year': 201801,
#   'ID_VehicleBrand': 40,
#   'ID_VehicleLineup': 539,
#   'Condition': 'used',
#   'ID_VehicleType': '2',
#   'ID_Color': 8}]

# %%
posts_table = pd.DataFrame(data=total_post)
vehicleinfo_table = pd.DataFrame(data=total_vehicleinfo)

# %%
posts_table
# Out:
#                                         Title  \
# 0                           Yamaha Latte 2020
# 1                          SYM Angel 110 2005
# 2    Harley Davidson Forty-Eight Special 2019
# 3             Harley Davidson Street 750 2015
# 4                         Suzuki GZ 150A 2017
# ..                                        ...
# 251                     Brixton BX 150 X 2021
# 252                        Honda MSX 125 2021
# 253                  Honda Air Blade 110 2010
# 254                      Ducati Mini 110 2021
# 255                       Yamaha TFX 150 2018
#
#                                                Content   Pricetag  \
# 0    Latte 2020 k&yacute; ngay chủ \nOdo chuẩn gần ...   35000000
# 1    Cầm Đồ Ho&agrave;ng Thắng Thanh L&yacute; Xe :...    4500000
# 2    XE MOTO PH&Acirc;N KHỐI LỚN CỰC HIẾM - Harley ...  435000000
# 3    ‼️ MOTOR HARLEY DAVIDSON STREET 750 CH&Iacute;...  178000000
# 4    &quot;suzuki Gz150-A 150cc m&agrave;u đen đời ...   47900000
# ..                                                 ...        ...
# 251  Ch&iacute;nh chủ m&igrave;nh muốn b&aacute;n c...   30600000
# 252  Cần b&aacute;n Honda MSX 125 Đ&egrave;n LED m&...   22600000
# 253  M&igrave;nh đang cần b&aacute;n chiếc xe n&agr...   11000000
# 254  Do kh&ocirc;ng c&ograve;n nhu cầu sử dụng n&ec...   12000000
# 255  Xe 1 chủ i chưa sửa chữa thay thế bất cứ g&igr...   36700000
#
#                                                  Image        City_name  \
# 0    https://cdn.okxe.vn/products/913/1113913/11139...  Tp. Hồ Chí Minh
# 1    https://cdn.okxe.vn/products/944/1102944/11029...  Tp. Hồ Chí Minh
# 2    https://cdn.okxe.vn/products/376/1069376/10693...  Tp. Hồ Chí Minh
# 3    https://cdn.okxe.vn/products/79/1012079/101207...  Tp. Hồ Chí Minh
# 4    https://cdn.okxe.vn/products/253/1190253/11902...  Tỉnh Bình Dương
# ..                                                 ...              ...
# 251  https://cdn.okxe.vn/products/155/1195155/11951...       Tp. Hà Nội
# 252  https://cdn.okxe.vn/products/153/1195153/11951...       Tp. Hà Nội
# 253  https://cdn.okxe.vn/products/152/1195152/11951...       Tp. Hà Nội
# 254  https://cdn.okxe.vn/products/151/1195151/11951...       Tp. Hà Nội
# 255  https://cdn.okxe.vn/products/150/1195150/11951...       Tp. Hà Nội
#
#      ID_VehicleInfo
# 0                 1
# 1                 2
# 2                 3
# 3                 4
# 4                 5
# ..              ...
# 251             252
# 252             253
# 253             254
# 254             255
# 255             256
#
# [256 rows x 6 columns]

# %%
posts_table.isnull().sum()
# Out:
# Title             0
# Content           0
# Pricetag          0
# Image             2
# City_name         0
# ID_VehicleInfo    0
# dtype: int64

# %%
vehicleinfo_table
# Out:
#      infoid                         Vehicle_name  Odometer License_plate  \
# 0         1                         Yamaha Latte     10000          None
# 1         2                        SYM Angel 110    100000          None
# 2         3  Harley Davidson Forty-Eight Special      5000          None
# 3         4           Harley Davidson Street 750      5000          None
# 4         5                       Suzuki GZ 150A     23000    60F2-61723
# ..      ...                                  ...       ...           ...
# 251     252                     Brixton BX 150 X      5000          None
# 252     253                        Honda MSX 125      5000          None
# 253     254                  Honda Air Blade 110      5000          None
# 254     255                      Ducati Mini 110      5000          None
# 255     256                       Yamaha TFX 150      5000          None
#
#     Cubic_power  Manufacture_year  ID_VehicleBrand  ID_VehicleLineup  \
# 0         125cc            202011               40              1711
# 1           110            200504               35               438
# 2          1200            201912               13               115
# 3           750            201503               13              1231
# 4           149            201712               34               414
# ..          ...               ...              ...               ...
# 251         150            202107                5                31
# 252       124.9            202112               15               165
# 253         108            201001               15               148
# 254         110            202102                9              1075
# 255       149.8            201801               40               539
#
#     Condition ID_VehicleType  ID_Color
# 0        used              1        10
# 1        used              2        13
# 2        used              3         3
# 3        used              3         3
# 4        used              2         3
# ..        ...            ...       ...
# 251      used              3         3
# 252      used              2         3
# 253      used              1         3
# 254      used              3         3
# 255      used              2         8
#
# [256 rows x 11 columns]

# %%
vehicleinfo_table.isnull().sum()
# Out:
# infoid                0
# Vehicle_name          0
# Odometer              0
# License_plate       250
# Cubic_power           6
# Manufacture_year      0
# ID_VehicleBrand       0
# ID_VehicleLineup      0
# Condition             0
# ID_VehicleType        0
# ID_Color              0
# dtype: int64

# %%
brands_table.to_csv("VehicleBrand.csv", index=None)
models_table.to_csv("VehicleLineup.csv", index=None)
posts_table.to_csv("Post.csv", index=None)
vehicleinfo_table.to_csv("VehicleInfo.csv", index=None)
