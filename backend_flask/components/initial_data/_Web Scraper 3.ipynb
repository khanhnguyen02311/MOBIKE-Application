# %%
import numpy as np
import pandas as pd

# %%
post_table = pd.read_csv('Post.csv', index_col=False)
vehicleinfo_table = pd.read_csv('VehicleInfo.csv', index_col=False)

# %%
post_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           256 non-null    object
#  1   Content         256 non-null    object
#  2   Pricetag        256 non-null    int64
#  3   Image           255 non-null    object
#  4   City_name       256 non-null    object
#  5   ID_VehicleInfo  256 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 12.1+ KB

# %%
vehicleinfo_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   infoid            256 non-null    int64
#  1   Vehicle_name      256 non-null    object
#  2   Odometer          256 non-null    int64
#  3   License_plate     0 non-null      float64
#  4   Cubic_power       252 non-null    float64
#  5   Manufacture_year  256 non-null    int64
#  6   ID_VehicleBrand   256 non-null    int64
#  7   ID_VehicleLineup  256 non-null    int64
#  8   Condition         256 non-null    int64
#  9   ID_VehicleType    256 non-null    int64
#  10  ID_Color          256 non-null    int64
# dtypes: float64(2), int64(8), object(1)
# memory usage: 22.1+ KB

# %%
post_table
# Out:
#                                         Title  \
# 0                           Yamaha Latte 2020
# 1                          SYM Angel 110 2005
# 2    Harley Davidson Forty-Eight Special 2019
# 3             Harley Davidson Street 750 2015
# 4                     Yamaha Exciter 150 2017
# ..                                        ...
# 251                   Yamaha Exciter 150 2018
# 252                      Benelli TNT 125 2019
# 253                  Honda Wave Alpha 50 2011
# 254                  Honda Air Blade 110 2011
# 255                       Suzuki GZ 150A 2020
#
#                                                Content   Pricetag  \
# 0    Latte 2020 k&yacute; ngay chủ \nOdo chuẩn gần ...   35000000
# 1    Cầm Đồ Ho&agrave;ng Thắng Thanh L&yacute; Xe :...    4500000
# 2    XE MOTO PH&Acirc;N KHỐI LỚN CỰC HIẾM - Harley ...  435000000
# 3    ‼️ MOTOR HARLEY DAVIDSON STREET 750 CH&Iacute;...  178000000
# 4    - Yamaha exciter 150\n- biển số th&agrave;nh p...   27500000
# ...

# %%
post_table.City_name.unique()
# hanoi: 1
# hcm: 50
# binhduong: 47
# bacgiang: 15
# danang: 32
# Out:
# array(['Tp. Hồ Chí Minh', 'Tp. Hà Nội', 'Tỉnh Bình Dương',
#        'Tỉnh Bắc Giang', 'Tp. Đà Nẵng'], dtype=object)

# %%
post_table.loc[post_table['City_name'] == 'Tp. Hồ Chí Minh', 'ID_City'] = 50
post_table.loc[post_table['City_name'] == 'Tp. Hà Nội', 'ID_City'] = 1
post_table.loc[post_table['City_name'] == 'Tỉnh Bình Dương', 'ID_City'] = 47
post_table.loc[post_table['City_name'] == 'Tỉnh Bắc Giang', 'ID_City'] = 15
post_table.loc[post_table['City_name'] == 'Tp. Đà Nẵng', 'ID_City'] = 32

# %%
post_table.loc[:, 'ID_City'] = post_table.loc[:, 'ID_City'].astype(int)

# %%
post_table
# Out:
#                                         Title  \
# 0                           Yamaha Latte 2020
# 1                          SYM Angel 110 2005
# 2    Harley Davidson Forty-Eight Special 2019
# 3             Harley Davidson Street 750 2015
# 4                     Yamaha Exciter 150 2017
# ..                                        ...
# 251                   Yamaha Exciter 150 2018
# 252                      Benelli TNT 125 2019
# 253                  Honda Wave Alpha 50 2011
# 254                  Honda Air Blade 110 2011
# 255                       Suzuki GZ 150A 2020
#
#                                                Content   Pricetag  \
# 0    Latte 2020 k&yacute; ngay chủ \nOdo chuẩn gần ...   35000000
# 1    Cầm Đồ Ho&agrave;ng Thắng Thanh L&yacute; Xe :...    4500000
# 2    XE MOTO PH&Acirc;N KHỐI LỚN CỰC HIẾM - Harley ...  435000000
# 3    ‼️ MOTOR HARLEY DAVIDSON STREET 750 CH&Iacute;...  178000000
# 4    - Yamaha exciter 150\n- biển số th&agrave;nh p...   27500000
# ...

# %%
post_table.to_csv('Post.csv', index=None)

# %%
vehicleinfo_table
# Out:
#      infoid                         Vehicle_name  Odometer  License_plate  \
# 0         1                         Yamaha Latte     10000            NaN
# 1         2                        SYM Angel 110    100000            NaN
# 2         3  Harley Davidson Forty-Eight Special      5000            NaN
# 3         4           Harley Davidson Street 750      5000            NaN
# 4         5                   Yamaha Exciter 150     30000            NaN
# ..      ...                                  ...       ...            ...
# 251     252                   Yamaha Exciter 150      5000            NaN
# 252     253                      Benelli TNT 125      5000            NaN
# 253     254                  Honda Wave Alpha 50     30000            NaN
# 254     255                  Honda Air Blade 110      5000            NaN
# 255     256                       Suzuki GZ 150A      5000            NaN
#
#      Cubic_power  Manufacture_year  ID_VehicleBrand  ID_VehicleLineup  \
# ...
